# %%
import cv2
import torch
from ultralytics import YOLO

# Load your custom trained model
model = YOLO("runs/pose/train-pose11x-v12-unfinished/weights/best.pt").eval()

# Set device (MPS for Apple Silicon or CPU)
device = "mps" if torch.backends.mps.is_available() else "cpu"
model.to(device)

# Initialize webcam (0 is usually the default camera)
cap = cv2.VideoCapture(0)

# Set desired resolution (optional)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Check if camera opened successfully
if not cap.isOpened():
    raise IOError("Cannot open webcam")

# Real-time detection loop
while True:
    # Read frame from webcam
    ret, frame = cap.read()
    if not ret:
        break
        
    # Convert frame to RGB and perform inference
    results = model.predict(frame, 
                            verbose=False,
                            conf=0.5)
    
    # Process results (now using next() instead of direct indexing)
    if results:
        annotated_frame = results[0].plot()
        # Display annotated frame
        cv2.imshow('Syringe live pose', annotated_frame)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import torch
import math
import numpy as np
from ultralytics import YOLO

# Load your custom trained model
model = YOLO("runs/pose/train-pose11x-v12-unfinished/weights/best.pt").eval()

# Set device (MPS for Apple Silicon or CPU)
device = "mps" if torch.backends.mps.is_available() else "cpu"
model.to(device)

# Initialize webcam (0 is usually the default camera)
cap = cv2.VideoCapture(0)

# Set desired resolution (optional)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Check if camera opened successfully
if not cap.isOpened():
    raise IOError("Cannot open webcam")

# Real-time detection loop
while True:
    # Read frame from webcam
    ret, frame = cap.read()
    if not ret:
        break
        
    # Convert frame to RGB and perform inference
    results = model.predict(frame, verbose=False, conf=0.5)
    
    # Process results
    if results:
        r = results[0]
        annotated_frame = r.plot()  # Draw keypoints and bounding boxes
        
        if r.keypoints is not None:
            kpts = r.keypoints.xy[0].cpu().numpy()
            
            # Ensure we have exactly four keypoints in the correct order
            if len(kpts) >= 4:
                ll = kpts[0]
                ul = kpts[1]
                ur = kpts[2]
                lr = kpts[3]
                
                # Draw debug labels
                label_offset = 10
                font = cv2.FONT_HERSHEY_SIMPLEX
                font_scale = 0.5
                font_color = (0, 0, 255)  # Red
                thickness = 1
                
                cv2.putText(annotated_frame, 'LL', (int(ll[0]) + label_offset, int(ll[1])), 
                           font, font_scale, font_color, thickness)
                cv2.putText(annotated_frame, 'UL', (int(ul[0]) + label_offset, int(ul[1])), 
                           font, font_scale, font_color, thickness)
                cv2.putText(annotated_frame, 'LR', (int(lr[0]) + label_offset, int(lr[1])), 
                           font, font_scale, font_color, thickness)
                cv2.putText(annotated_frame, 'UR', (int(ur[0]) + label_offset, int(ur[1])), 
                           font, font_scale, font_color, thickness)
                
                # Calculate distance between lower points (width in pixels)
                dx = lr[0] - ll[0]
                dy = lr[1] - ll[1]
                D_pixels = math.hypot(dx, dy)
                
                if D_pixels > 0:
                    # Pixel-to-cm conversion factor
                    scale_cm_per_pixel = 1.0 / D_pixels  # 1 cm = initial width
                    
                    # Calculate line equation for upper edge (ax + by + c = 0)
                    x1, y1 = ul
                    x2, y2 = ur
                    a = y2 - y1
                    b = x1 - x2
                    c = (x2 - x1)*y1 - (y2 - y1)*x1
                    
                    # Calculate perpendicular distance from lower-left to upper edge
                    x0, y0 = ll
                    numerator = abs(a * x0 + b * y0 + c)
                    denominator = math.hypot(a, b)
                    
                    if denominator > 0:
                        h_pixels = numerator / denominator
                        h_cm = h_pixels * scale_cm_per_pixel
                        
                        # Calculate volume (πr²h, r=0.5cm)
                        volume = math.pi * (0.5 ** 2) * h_cm
                        
                        # Display volume on the frame
                        cv2.putText(annotated_frame, f"Volume: {volume:.2f} mL", 
                                   (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
        # Display annotated frame
        cv2.imshow('Syringe live pose', annotated_frame)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import torch
import math
import numpy as np
from ultralytics import YOLO

def calculate_parallel_distance(line1, line2):
    """Calculate distance between two parallel lines"""
    # Convert lines to ax + by + c = 0 form
    a1, b1, c1 = line1
    a2, b2, c2 = line2
    
    # Ensure lines are parallel
    if abs(a1*b2 - a2*b1) > 1e-6:
        return None  # Lines not parallel
    
    # Distance between parallel lines formula
    return abs(c2 - c1) / math.hypot(a1, b1)

def line_equation(p1, p2):
    """Return (a, b, c) for line equation ax + by + c = 0"""
    x1, y1 = p1
    x2, y2 = p2
    a = y2 - y1
    b = x1 - x2
    c = (x2 - x1)*y1 - (y2 - y1)*x1
    return (a, b, c)

# Load your custom trained model
model = YOLO("runs/pose/train-pose11x-v12-unfinished/weights/best.pt").eval()

# Set device (MPS for Apple Silicon or CPU)
device = "mps" if torch.backends.mps.is_available() else "cpu"
model.to(device)

# Initialize webcam
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

while True:
    ret, frame = cap.read()
    if not ret:
        break
        
    results = model.predict(frame, verbose=False, conf=0.5)
    
    if results:
        r = results[0]
        annotated_frame = r.plot()
        
        if r.keypoints is not None:
            kpts = r.keypoints.xy[0].cpu().numpy()
            
            if len(kpts) >= 4:
                ll = kpts[0]
                ul = kpts[1]
                ur = kpts[2]
                lr = kpts[3]
                
                # Draw debug labels
                label_offset = 10
                font = cv2.FONT_HERSHEY_SIMPLEX
                cv2.putText(annotated_frame, 'LL', (int(ll[0])+label_offset, int(ll[1])), font, 0.5, (0,0,255), 1)
                cv2.putText(annotated_frame, 'UL', (int(ul[0])+label_offset, int(ul[1])), font, 0.5, (0,0,255), 1)
                cv2.putText(annotated_frame, 'LR', (int(lr[0])+label_offset, int(lr[1])), font, 0.5, (0,0,255), 1)
                cv2.putText(annotated_frame, 'UR', (int(ur[0])+label_offset, int(ur[1])), font, 0.5, (0,0,255), 1)

                # Enhanced calculations
                try:
                    # Get both edges' lengths for scale calculation
                    lower_edge_px = math.hypot(lr[0]-ll[0], lr[1]-ll[1])
                    upper_edge_px = math.hypot(ur[0]-ul[0], ur[1]-ul[1])
                    
                    # Average scale factor from both edges
                    scale_cm_per_pixel = 2.0 / (lower_edge_px + upper_edge_px)
                    
                    # Create line equations for both edges
                    lower_line = line_equation(ll, lr)
                    upper_line = line_equation(ul, ur)
                    
                    # Calculate distance between parallel lines
                    h_pixels = calculate_parallel_distance(lower_line, upper_line)
                    
                    if h_pixels is not None and scale_cm_per_pixel > 0:
                        h_cm = h_pixels * scale_cm_per_pixel
                        
                        # Cross-validate with point-to-line distances
                        d1 = abs(upper_line[0]*ll[0] + upper_line[1]*ll[1] + upper_line[2]) / math.hypot(upper_line[0], upper_line[1])
                        d2 = abs(upper_line[0]*lr[0] + upper_line[1]*lr[1] + upper_line[2]) / math.hypot(upper_line[0], upper_line[1])
                        avg_h_pixels = (d1 + d2) / 2
                        
                        # Use weighted average of both methods
                        final_h_cm = (h_cm + (avg_h_pixels * scale_cm_per_pixel)) / 2
                        
                        # Calculate volume (mL)
                        volume = math.pi * (0.5**2) * final_h_cm
                        
                        # Display measurements
                        cv2.putText(annotated_frame, f"Volume: {volume:.2f} mL", (10,30), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
                        cv2.putText(annotated_frame, f"H: {final_h_cm:.2f}cm", (10,70), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2)

                except Exception as e:
                    print(f"Calculation error: {str(e)}")
    
        cv2.imshow('Syringe live pose', annotated_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import torch
import math
import numpy as np
from collections import deque
from ultralytics import YOLO

class SyringeVolumeCalculator:
    def __init__(self):
        self.model = YOLO("runs/pose/train-pose11x-v12-unfinished/weights/best.pt").eval()
        self.device = "mps" if torch.backends.mps.is_available() else "cpu"
        self.model.to(self.device)
        self.volume_history = deque(maxlen=15)
        self.syringe_diameter = 1.0  # cm

    def initialize_camera(self):
        cap = cv2.VideoCapture(0)
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
        if not cap.isOpened():
            raise IOError("Camera initialization failed")
        return cap

    @staticmethod
    def calculate_line_equation(p1, p2):
        """Returns (A, B, C) coefficients for line equation Ax + By + C = 0"""
        x1, y1 = p1
        x2, y2 = p2
        a = y2 - y1
        b = x1 - x2
        c = (x2 - x1)*y1 - (y2 - y1)*x1
        return (a, b, c)

    def calculate_parallel_distance(self, line1, line2):
        """Calculate distance between two parallel lines in pixels"""
        a1, b1, c1 = line1
        a2, b2, c2 = line2
        
        # Verify lines are parallel
        if abs(a1*b2 - a2*b1) > 1e-6:
            return None
        
        return abs(c2 - c1) / math.hypot(a1, b1)

    def calculate_height(self, lower_line_eq, upper_line_eq, scale_factor):
        """Calculate height using multiple methods and return consensus"""
        # Method 1: Parallel line distance
        h_pixels = self.calculate_parallel_distance(lower_line_eq, upper_line_eq)
        
        # Method 2: Average point distances (requires physical points)
        try:
            d_ll = self.point_to_line_distance(self.ll_point, upper_line_eq)
            d_lr = self.point_to_line_distance(self.lr_point, upper_line_eq)
            avg_point_dist = (d_ll + d_lr) / 2
        except AttributeError:
            avg_point_dist = h_pixels if h_pixels else 0

        if h_pixels is None or abs(h_pixels - avg_point_dist) > 5:
            return avg_point_dist * scale_factor
        
        return ((h_pixels * 0.7) + (avg_point_dist * 0.3)) * scale_factor

    @staticmethod
    def point_to_line_distance(point, line):
        """Calculate perpendicular distance from point to line"""
        x, y = point
        a, b, c = line
        return abs(a*x + b*y + c) / math.hypot(a, b)

    def process_frame(self, frame):
        results = self.model.predict(frame, verbose=False, conf=0.6)
        if not results:
            return frame, None
        
        r = results[0]
        annotated_frame = r.plot()
        
        if r.keypoints is None or len(r.keypoints.xy[0]) < 4:
            return annotated_frame, None

        kpts = r.keypoints.xy[0].cpu().numpy()
        self.ll_point, self.ul_point, self.ur_point, self.lr_point = kpts[:4]

        # Draw debug information
        self.draw_debug_info(annotated_frame)

        try:
            # Calculate line equations from physical points
            lower_line_eq = self.calculate_line_equation(self.ll_point, self.lr_point)
            upper_line_eq = self.calculate_line_equation(self.ul_point, self.ur_point)

            # Calculate scale factors from both edges
            lower_edge_px = np.linalg.norm(self.lr_point - self.ll_point)
            upper_edge_px = np.linalg.norm(self.ur_point - self.ul_point)
            scale_factor = 2.0 / (lower_edge_px + upper_edge_px)

            # Calculate height using consensus method
            height_cm = self.calculate_height(lower_line_eq, upper_line_eq, scale_factor)
            
            if 0 < height_cm < 30:  # Physical constraint check
                volume = math.pi * (self.syringe_diameter/2)**2 * height_cm
                self.volume_history.append(volume)
                return annotated_frame, np.median(self.volume_history)
            
        except Exception as e:
            print(f"Processing error: {str(e)}")
        
        return annotated_frame, None

    def draw_debug_info(self, frame):
        """Visual debug information overlay"""
        debug_params = {
            'fontFace': cv2.FONT_HERSHEY_SIMPLEX,
            'fontScale': 0.6,
            'color': (0, 0, 255),
            'thickness': 1
        }

        # Keypoint labels
        for label, pt in zip(['LL', 'UL', 'UR', 'LR'], 
                           [self.ll_point, self.ul_point, self.ur_point, self.lr_point]):
            cv2.putText(frame, label, 
                       (int(pt[0])+10, int(pt[1])), 
                       **debug_params)

        # Edge length display
        lower_len = np.linalg.norm(self.lr_point - self.ll_point)
        upper_len = np.linalg.norm(self.ur_point - self.ul_point)
        cv2.putText(frame, f"Lower: {lower_len:.1f}px", (10, 100), **debug_params)
        cv2.putText(frame, f"Upper: {upper_len:.1f}px", (10, 130), **debug_params)

    def run(self):
        cap = self.initialize_camera()
        
        try:
            while True:
                ret, frame = cap.read()
                if not ret:
                    break

                processed_frame, volume = self.process_frame(frame)
                
                if volume is not None:
                    cv2.putText(processed_frame, f"Volume: {volume:.2f} mL", 
                               (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 
                               1, (0, 255, 0), 2)
                    cv2.putText(processed_frame, f"Height: {volume / (math.pi*0.25):.1f} cm", 
                               (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 
                               0.8, (0, 255, 0), 2)

                cv2.imshow('Syringe Volume Measurement', processed_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
                    
        finally:
            cap.release()
            cv2.destroyAllWindows()

if __name__ == "__main__":
    calculator = SyringeVolumeCalculator()
    calculator.run()
# Out:
# 2025-01-25 14:01:18.189 python[38341:1072831] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-01-25 14:01:18.189 python[38341:1072831] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# /var/folders/ht/hpy25npj1t96b4yb_vxvc_b00000gn/T/ipykernel_38341/3429443511.py:43: RuntimeWarning: invalid value encountered in divide
#   return abs(c2 - c1) / math.hypot(a1, b1)
